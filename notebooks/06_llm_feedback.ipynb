# %%
from PyPDF2 import PdfReader

# %%
# Out:
# 1
#   AYUSH  YADAV
# Kanpur, India | +91 8619644566 | 2k24.cs1g.2413916@gmail.com
# LinkedIn  | GitHub
# CAREER  OBJECTIVE
# Aspiring  Software  Engineer  with a strong  foundation  in C++,  Java,  Python,  and Data Structures. Seeking
# a Software  Engineering  Internship  at Oracle  to leverage  technical  expertise  in developing secure, intelligent
# applications and contributing to collaborative, high -impact projects.
# TECHNICAL  COMPETENCIES
# • Languages:  C, C++, Java,  Python,  JavaScript,  SQL, TypeScript,  HTML/CSS
# • Core  Computer  Science:  Data Structures & Algorithms (DSA), DBMS, Object -Oriented Program ming
# (OOP) , SDLC Fundamentals (Testing and QA focused).
# • Tools  & Frameworks:  React,  Node.js,  Express.js,  Git, GitHub,  VS Code,  Tailwind  CSS,  MS Office , YOLOv11
# ACADEMIC  DETAILS
# Pranveer  Singh  Institute  of Technology  (PSIT)  Kanpur,  India
# B.Tech . in Computer  Science  and Engineering  (CGPA:  7.84)
# ...

# %%
from google import genai

print(genai.__version__)
# Out:
# 2.17.0

# %%
def generative_ai_feedback(report):
    prompt = f"""

    You are an experienced AI Career Coach.

Analyze the following report.
and generate the response and analyze it specifically and also analyze it and give me sections

1. Resume Summary
2. Strength Analysis
3.Weakness Analysis
4.Career Advice
5.Learning Roadmap
6.Three Projects
7.Five Interview Questions

Recommended Role:
{report['recommended_role']}

Semantic Score:
{report['semantic_score']}

Career Readiness:
{report['career_readiness']}

Strengths:
{report['strengths']}

Improvement Areas:
{report['improvement_areas']}

Category Analysis:
{report['category_analysis']}

"""
    response = client.models.generate_content(
        model = "gemini-flash-lite-latest"
        contents = prompt
    )
    feedback = response.text
    print(feedback)
